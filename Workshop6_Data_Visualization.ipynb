# %% [markdown]
# # Workshop 6: Data Visualization
# วัตถุประสงค์ ต้องการเรียนรู้การทำData Visualizationโดยใช้ `looker studio` และใช้ข้อมูลจากworkshopก่อนๆมาประกอบ

# %% [markdown]
# ## ก่อนอื่น
# - ก่อนการสร้าง Dashboard Business Analyst (BA) จะไปคุยกับผู้ใช้ (ทีม Product และ Marketing) ว่ามีความต้องการอะไรบ้าง?
# - จากนั้นจะนำมาวาด Wireframe ก่อนเพื่อเช็คว่า Dashboard ที่กำลังจะสร้างนั้นตรงกับความต้องการของผู้ใช้หรือไม่ เพราะการแก้ไขใน Wireframe ย่อมง่ายกว่า
# * Wireframe คือ แบบร่างDashboard คร่าวๆ

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data engineer(DE) Role
# DE จะสร้าง **View** เพื่อเลือก**ข้อมูลแค่เท่าที่จำเป็น**ไปสำหรับใช้ทำ **Dashboard**

# %%
CREATE VIEW r2de-397015.workshop5.vw_ws6
AS
SELECT timestamp, user_id, country, Book_ID, Book_Title, Categories, THBPrice
FROM r2de-397015.workshop5.audible_data

#CREATE VIEW r2de-397015.<dataset>ใส่ชื่อ.<view_name>ใส่ชื่อ
#AS
#SELECT timestamp, user_id, country, Book_ID, Book_Title, Categories, THBPrice
#FROM r2de-397015.workshop5.audible_data *pathข้อมูลในBigquery

# %% [markdown]
# จาก**CODE** ด้านบน เราจะเลือกข้อมูลที่จำเป็น คือ `timestamp, user_id, country, Book_ID, Book_Title, Categories, THBPrice`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ต่อมา
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Finally
# เราจะได้Dashboard ตามความต้องการของทีมและนำไปวิเคราะห์ต่อไป

# %% [markdown]
# ![ws6_Audible_viz_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# > จาก Data visualization จะเห็นว่า
# - หนังสือที่สร้างรายได้มากที่สุด ก็คือ `Ready Player One`
# - ประเภทหนังสือที่สร้างรายได้มากที่สุด ก็คือ พวกFiction
# เป็นต้น

# %% [markdown]
# ![ws6_Audible_viz_page-0002.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ------------------------------------------
# ## จบ Workshop6
